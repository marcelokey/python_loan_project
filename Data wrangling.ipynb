# %%
import pandas as pd

# %%
df= pd .read_csv('assignment.csv')

# %%
df
# Out:
#     IMBD title ID               Original titlÊ  Release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
del df['IMBD title ID']

# %%
df.head(2)
# Out:
#              Original titlÊ Release year        Genrë¨ Duration Country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   Content Rating              Director  Unnamed: 8       Income     Votes   \
# 0              R        Frank Darabont         NaN   $ 28815245  2.278.845
# 1              R  Francis Ford Coppola         NaN  $ 246120974  1.572.674
#
#   Score
# 0   9.3
# 1   9.2

# %%
df.drop(columns= 'Unnamed: 8',inplace=True)

# %%
df.head(2)
# Out:
#              Original titlÊ Release year        Genrë¨ Duration Country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   Content Rating              Director       Income     Votes  Score
# 0              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %%
df.rename(columns= {'Original titlÊ':'Original Title','Genrë¨':'Genre'}, inplace=True)

# %%
df.head(2)
# Out:
#              Original Title Release year         Genre Duration Country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   Content Rating              Director       Income     Votes  Score
# 0              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %%
df.columns=df.columns.str.lower()

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.head(2)
# Out:
#              original_title release_year         genre duration country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   content_rating              director       income    _votes_ score
# 0              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %%
df.rename(columns={'_votes_':'votes'}, inplace=True)

# %%
df.head(2)
# Out:
#              original_title release_year         genre duration country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   content_rating              director       income      votes score
# 0              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %%
df[df['original_title'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [original_title, release_year, genre, duration, country, content_rating, director, income, votes, score]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    object
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: object(10)
# memory usage: 8.0+ KB

# %%
df.head(2)
# Out:
#              original_title release_year         genre duration country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   content_rating              director       income      votes score
# 0              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %%
df['release_year']= pd.to_datetime(df.release_year, errors='coerce')

# %%
df
# Out:
#                   original_title release_year                       genre  \
# 0       The Shawshank Redemption   1995-02-10                       Drama
# 1                  The Godfather          NaT                Crime, Drama
# 2                The Dark Knight          NaT        Action, Crime, Drama
# 3         The Godfather: Part II   1975-09-25                Crime, Drama
# 4                   Pulp Fiction   1994-10-28                Crime, Drama
# ..                           ...          ...                         ...
# 96                     The Sting   1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot   1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹   1965-12-20                     Western
# 99       Jodaeiye Nader az Simin   2011-10-21                       Drama
# 100          Singin' in the Rain   1953-02-05    Comedy, Musical, Romance
#
#     duration       country content_rating              director  \
# ...

# %%
df.head(5)
# Out:
#              original_title release_year                 genre duration  \
# 0  The Shawshank Redemption   1995-02-10                 Drama      142
# 1             The Godfather          NaT          Crime, Drama      175
# 2           The Dark Knight          NaT  Action, Crime, Drama      152
# 3    The Godfather: Part II   1975-09-25          Crime, Drama      220
# 4              Pulp Fiction   1994-10-28          Crime, Drama
#
#   country content_rating              director         income      votes score
# 0     USA              R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1     USA              R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2      US          PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3     USA              R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0
# 4     USA              R     Quentin Tarantino    $ 222831817  1.780.147  8,9f

# %%
df['genre']= df['genre'].str.split(',', expand=True)[0]

# %%
df.head(4)
# Out:
#              original_title release_year   genre duration country  \
# 0  The Shawshank Redemption   1995-02-10   Drama      142     USA
# 1             The Godfather          NaT   Crime      175     USA
# 2           The Dark Knight          NaT  Action      152      US
# 3    The Godfather: Part II   1975-09-25   Crime      220     USA
#
#   content_rating              director         income      votes score
# 0              R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2          PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3              R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                     original_title release_year      genre  \
# 1                                    The Godfather          NaT      Crime
# 2                                  The Dark Knight          NaT     Action
# 5    The Lord of the Rings: The Return of the King          NaT     Action
# 9                                       Fight Club          NaT      Drama
# 12                 Il buono, il brutto, il cattivo          NaT    Western
# 13                                             NaN          NaT        NaN
# 14                                      The Matrix   1999-05-07     Action
# 15           The Lord of the Rings: The Two Towers          NaT     Action
# 18                 One Flew Over the Cuckoo's Nest          NaT      Drama
# 27                                La vita B9 bella   1997-12-20     Comedy
# 28                                    Gisaengchung   2019-11-07     Comedy
# ...

# %%
df.drop(index=13,inplace=True)

# %%
df
# Out:
#                   original_title release_year      genre duration  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142
# 1                  The Godfather          NaT      Crime      175
# 2                The Dark Knight          NaT     Action      152
# 3         The Godfather: Part II   1975-09-25      Crime      220
# 4                   Pulp Fiction   1994-10-28      Crime
# ..                           ...          ...        ...      ...
# 96                     The Sting   1974-03-21     Comedy      129
# 97                      Das Boot   1982-03-18  Adventure      149
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123
# 100          Singin' in the Rain   1953-02-05     Comedy      103
#
#           country content_rating              director         income  \
# 0             USA              R        Frank Darabont     $ 28815245
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    89 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 8.6+ KB

# %%
df.duration= df.duration.fillna(0).astype(int,errors='ignore')

# %%
df.head(4)
# Out:
#              original_title release_year   genre duration country  \
# 0  The Shawshank Redemption   1995-02-10   Drama      142     USA
# 1             The Godfather          NaT   Crime      175     USA
# 2           The Dark Knight          NaT  Action      152      US
# 3    The Godfather: Part II   1975-09-25   Crime      220     USA
#
#   content_rating              director         income      votes score
# 0              R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2          PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3              R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0

# %%
df.country.value_counts()
# Out:
# country
# USA            64
# UK             12
# Italy           5
# Japan           4
# New Zealand     3
# France          3
# Germany         3
# South Korea     2
# Brazil          1
# India           1
# Denmark         1
# Iran            1
# Name: count, dtype: int64

# %%
df.loc[24,'country']= 'USA'

# %%
df[df['country']== 'West Germany']
# Out:
#    original_title release_year      genre duration       country  \
# 97       Das Boot   1982-03-18  Adventure      149  West Germany
#
#    content_rating           director      income    votes score
# 97              R  Wolfgang Petersen  $ 11487676  226.427   7.5

# %%
df.loc[97,'country']= 'Germany'

# %%
df.head(4)
# Out:
#              original_title release_year   genre duration country  \
# 0  The Shawshank Redemption   1995-02-10   Drama      142     USA
# 1             The Godfather          NaT   Crime      175     USA
# 2           The Dark Knight          NaT  Action      152     USA
# 3    The Godfather: Part II   1975-09-25   Crime      220     USA
#
#   content_rating              director         income      votes score
# 0              R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2          PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3              R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0

# %%
df.income= df.income.str[2:]

# %%
df.loc[3,'income']= 408035783

# %%
df.income
# Out:
# 0        28815245
# 1       246120974
# 2      1005455211
# 3       408035783
# 4       222831817
#           ...
# 96      156000000
# 97       11487676
# 98       15000000
# 99       22926076
# 100       1864182
# Name: income, Length: 100, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    89 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 12.7+ KB

# %%
df.income= df.income.astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    89 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 12.7+ KB

# %%
df.votes= df. votes.str.replace('.','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    89 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 12.7+ KB

# %%
df.votes= df.votes.astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    89 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   votes           100 non-null    int64
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 12.7+ KB

# %%
df.score.value_counts()
# Out:
# score
# 8.6       11
# 8.2        8
# 8.3        8
# 8.1        7
# 8.4        7
# 8.5        6
# 7.5        6
# 7.8        6
# 8.0        6
# 7.9        5
# 7.6        4
# 7.7        4
# 7.4        3
# 8.8        3
# 8.7        2
# 8.9        2
# 9.2        1
# 8,6        1
# 8,7e-0     1
# 8.7.       1
# ++8.7      1
# 8:8        1
# 8..8       1
# 08.9       1
# 8,9f       1
# 9,.0       1
# 9.0        1
# 9.3        1
# Name: count, dtype: int64

# %%
df[df.score == '8,6']
# Out:
#               original_title release_year  genre duration country  \
# 21  The Silence of the Lambs   1991-03-05  Crime      118     USA
#
#    content_rating        director     income    votes score
# 21              R  Jonathan Demme  272753884  1234134   8,6

# %%
df.loc[21,'score']= '8.6'

# %%
df.score= df.score.astype(float)

# %%
df
# Out:
#                   original_title release_year      genre duration  country  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142      USA
# 1                  The Godfather          NaT      Crime      175      USA
# 2                The Dark Knight          NaT     Action      152      USA
# 3         The Godfather: Part II   1975-09-25      Crime      220      USA
# 4                   Pulp Fiction   1994-10-28      Crime               USA
# ..                           ...          ...        ...      ...      ...
# 96                     The Sting   1974-03-21     Comedy      129      USA
# 97                      Das Boot   1982-03-18  Adventure      149  Germany
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132    Italy
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123     Iran
# 100          Singin' in the Rain   1953-02-05     Comedy      103      USA
#
#     content_rating              director      income    votes  score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    89 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   votes           100 non-null    int64
#  9   score           100 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 12.7+ KB

# %%
df.describe()
# Out:
#                         release_year        income         votes       score
# count                             89  1.000000e+02  1.000000e+02  100.000000
# mean   1991-08-26 07:00:40.449438208  2.991255e+08  8.297713e+05    8.240000
# min              1937-03-12 00:00:00  5.760000e+02  1.957890e+05    7.400000
# 25%              1980-09-19 00:00:00  2.374174e+07  3.890690e+05    7.900000
# 50%              1995-12-01 00:00:00  1.093370e+08  7.515385e+05    8.300000
# 75%              2006-10-27 00:00:00  4.052080e+08  1.102243e+06    8.600000
# max              2020-01-23 00:00:00  2.797801e+09  2.278845e+06    9.300000
# std                              NaN  4.360335e+08  4.829340e+05    0.451485

# %%
import seaborn as sns

# %%
sns.countplot(data=df,y='genre')
# Out:
# <Axes: xlabel='count', ylabel='genre'>
